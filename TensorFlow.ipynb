# %%
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.4.0

# %%
a=np.arange(9).reshape(3,3)
print(a[:,1:])
# Out:
# [[1 2]
#  [4 5]
#  [7 8]]

# %%
x=np.arange(200)
y=np.random.randn(200)*10+np.arange(200)+21

# %%
dataset=pd.Series(y,x)
dataset
# Out:
# 0       32.554770
# 1       21.189726
# 2       22.752868
# 3       46.868224
# 4       34.823332
#           ...
# 195    212.712723
# 196    222.229494
# 197    217.538616
# 198    238.775906
# 199    215.697855
# Length: 200, dtype: float64
